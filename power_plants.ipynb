# %%
import pandas as pd

# %%
df = pd.read_excel("/home/samrose/fractaldyn/3_5_Multifuel_Y2021.xlsx")

# %%
df
# Out:
#      2021 Form EIA-860 Data - Schedule 3, 'Fuel Switching Data' (Operable Units Only)  \
# 0                                            Utility ID
# 1                                                   195
# 2                                                   195
# 3                                                   195
# 4                                                   195
# ...                                                 ...
# 3090                                              61967
# 3091                                              63113
# 3092                                              63222
# 3093                                              63230
# 3094                                              64262
#
#                                          Unnamed: 1  Unnamed: 2  \
# 0                                      Utility Name  Plant Code
# 1                                  Alabama Power Co          10
# 2                                  Alabama Power Co          10
# ...
