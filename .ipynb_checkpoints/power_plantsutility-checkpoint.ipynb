# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df = pd.read_excel("/home/samrose/fractaldyn/3_5_Multifuel_Y2021.xlsx")

# %%
df.head()
# Out:
#   2021 Form EIA-860 Data - Schedule 3, 'Fuel Switching Data' (Operable Units Only)  \
# 0                                         Utility ID
# 1                                                195
# 2                                                195
# 3                                                195
# 4                                                195
#
#          Unnamed: 1  Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      Utility Name  Plant Code     Plant Name      State     County
# 1  Alabama Power Co          10  Greene County         AL     Greene
# 2  Alabama Power Co          10  Greene County         AL     Greene
# 3  Alabama Power Co          10  Greene County         AL     Greene
# 4  Alabama Power Co          10  Greene County         AL     Greene
#
#      Unnamed: 6 Unnamed: 7                            Unnamed: 8   Unnamed: 9  \
# 0  Generator ID     Status                            Technology  Prime Mover
# ...
