# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df = pd.read_excel("/home/samrose/fractaldyn/3_1_Generator_Y2021.xlsx")

# %%
df.head()
# Out:
#   2021 Form EIA-860 Data - Schedule 3, 'Generator Data' (Operable Units Only)  \
# 0                                         Utility ID
# 1                                              63560
# 2                                              63560
# 3                                              63560
# 4                                              63560
#
#                        Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                    Utility Name  Plant Code  Plant Name      State
# 1  TDX Sand Point Generating, LLC           1  Sand Point         AK
# 2  TDX Sand Point Generating, LLC           1  Sand Point         AK
# 3  TDX Sand Point Generating, LLC           1  Sand Point         AK
# 4  TDX Sand Point Generating, LLC           1  Sand Point         AK
#
#        Unnamed: 5    Unnamed: 6         Unnamed: 7   Unnamed: 8 Unnamed: 9  \
# 0          County  Generator ID         Technology  Prime Mover  Unit Code
# ...
